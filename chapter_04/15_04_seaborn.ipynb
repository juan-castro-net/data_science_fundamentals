# %% [markdown]
# <a href="https://colab.research.google.com/github/juancasi/data_science_fundamentals/blob/master/chapter_04/15_04_seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Seaborn

# %% [markdown]
# ##Visualize Distributions With Seaborn
# Seaborn is a library that uses Matplotlib underneath to plot graphs. It will be used to visualize random distributions.

# %% [markdown]
# ![Seaborn Image](https://drive.google.com/uc?id=1x6wCfF7I7NpiV8-AgH7Qkgk7EQ22ZTQ0)

# %% [markdown]
# ##Install Seaborn.
# If you have Python and PIP already installed on a system, install it using this command:
#
# > `pip install seaborn`

# %% [markdown]
# If you use Jupyter, install Seaborn using this command:
# > `!pip install seaborn`

# %% [markdown]
# ##Distplots
# Distplot stands for distribution plot, it takes as input an array and plots a curve corresponding to the distribution of points in the array.
#
# ##Import Matplotlib
# import the pyplot object of the Matplotlib module in your code using following code
#
# > `import matplotlib.pyplot as plt`
#
# ##Import Seaborn
# import the seaborn in your code using following code
#
# > `import seaborn as sns`

# %% [markdown]
# ##Plotting a Displot

# %% [markdown]
# **Example**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot([0, 1, 2, 3, 4, 5])

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ##Plotting a Distplot Without the Histogram

# %% [markdown]
# **Example**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot([0, 1, 2, 3, 4, 5], hist=False)

plt.show()

# %% [markdown]
# > **Note:** We will be using: `sns.distplot(arr, hist=False)` to visualize random distributions in this tutorial.
