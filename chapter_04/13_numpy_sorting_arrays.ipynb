# %% [markdown]
# <a href="https://colab.research.google.com/github/juancasi/data_science_fundamentals/blob/master/chapter_04/13_numpy_sorting_arrays.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #NumPy Sorting Arrays

# %% [markdown]
# ##Sorting Arrays
# Sorting means putting elements in a ordered sequence.
#
# Ordered sequence is any sequence that has an order corresponding to elements, like numeric or alphabetical, ascending or descending.
#
# The NumPy ndarray object has a function called sort(), that will sort a specified array.

# %% [markdown]
# **Example**
#
# Sort the array:

# %%
import numpy as np

arr = np.array([3, 2, 0, 1])

print(np.sort(arr))
# Out:
# [0 1 2 3]

# %% [markdown]
# > *Note: This method returns a copy of the array, leaving the original array unchanged.
#
# You can also sort arrays of strings, or any other data type:
#
# Example
# Sort the array alphabetically:

# %% [markdown]
# > **Note:** This method returns a copy of the array, leaving the original array unchanged.
#
# You can also sort arrays of strings, or any other data type:

# %% [markdown]
# **Example**
#
# Sort the array alphabetically:

# %%
import numpy as np

arr = np.array(['banana', 'cherry', 'apple'])

print(np.sort(arr))
# Out:
# ['apple' 'banana' 'cherry']

# %% [markdown]
# **Example**
#
# Sort a boolean array:

# %%
import numpy as np

arr = np.array([True, False, True])

print(np.sort(arr))
# Out:
# [False  True  True]

# %% [markdown]
# ##Sorting a 2-D Array
# If you use the sort() method on a 2-D array, both arrays will be sorted:

# %% [markdown]
# **Example**
#
# Sort a 2-D array:

# %%
import numpy as np

arr = np.array([[3, 2, 4], [5, 0, 1]])

print(np.sort(arr))
# Out:
# [[2 3 4]
#  [0 1 5]]
